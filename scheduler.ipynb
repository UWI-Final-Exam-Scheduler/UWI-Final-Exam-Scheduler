# %% [markdown]
# ## Initial setup so we have something

# %%
from pulp import *

problem = LpProblem("Exam_Scheduling_Problem", LpMinimize)

#these sets need to be populated with actual data
E = [placeholder]  # exams
S = [placeholder]  # students
V = [placeholder]  # venues

D = range(1, 16)      # days 1–15
J= range(1, 4)       # 3 sessions per day

Timeslots = [(d, j) for d in D for j in J]

# cost[(e,v,t)]
cost = {}  

# bs[(s,e)] = 1 if student s registered for exam e, else 0
bs = {}

# Ne[e] = number of students in exam e
Ne = {}

# cV[v] = capacity of venue v
cV = {}

x = pulp.LpVariable.dicts(
    "x",
    ((e, v, t) for e in E for v in V for t in Timeslots),
    cat="Binary"
)

#Objective Function
problem += lpSum(cost[e, v, t] * x[e, v, t] for e in E for v in V for t in Timeslots)

#Constraint 1: Each exam must be assigned to exactly one venue and time
for e in E:
    problem+= lpSum(x[e, v, t] for v in V for t in Timeslots) == 1, f"Exam_{e}_scheduled_once"

#Constraint 2: No student can have overlapping exams
for s in S: 
    for t in Timeslots:
        problem += lpSum(bs[s, e] * x[e, v, t] for e in E for v in V) <= 1, f"Student_{s}_no_overlap_at_time_{t}"

#Constraint 3: Venue capacity must not be exceeded
for v in V:
    for t in Timeslots:
        problem += lpSum(x[e, v, t] for e in E) <= cV[v], f"Venue_{v}_capacity_at_time_{t}"

problem.solve()

print("Status:", LpStatus[problem.status])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 32
#      25 x = pulp.LpVariable.dicts(
#      26     "x",
#      27     ((e, v, t) for e in Exams for v in Venues for t in Timeslots),
#      28     cat="Binary"
#      29 )
#      31 #Objective Function
# ---> 32 problem += lpSum(cost[e, v, t] * x[e, v, t] for e in Exams for v in Venues for t in Timeslots)
#      34 #Constraint 1: Each exam must be assigned to exactly one venue and time
#      35 for e in Exams:
#
# File c:\Users\lolne\OneDrive\Documents\GitHub\UWI-Final-Exam-Scheduler\.venv\lib\site-packages\pulp\pulp.py:2469, in lpSum(vector)
#    2455 def lpSum(
#    2456     vector: (
#    2457         Iterable[LpAffineExpression | LpVariable | int | float]
#    (...)
#    2462     ),
#    2463 ):
#    2464     """
#    2465     Calculate the sum of a list of linear expressions
#    2466
#    2467     :param vector: A list of linear expressions
#    2468     """
# -> 2469     return LpAffineExpression().addInPlace(vector)
#
# File c:\Users\lolne\OneDrive\Documents\GitHub\UWI-Final-Exam-Scheduler\.venv\lib\site-packages\pulp\pulp.py:968, in LpAffineExpression.addInPlace(self, other, sign)
#     965         self.addInPlace(e, sign=sign)
#     966 elif isinstance(other, Iterable):
#     967     # if a list, we add each element of the list
# --> 968     for e in other:
#     969         self.addInPlace(e, sign=sign)
#     970 # if we're here, other must be a number
#     971 # we check if it's an actual number:
#
# Cell In[4], line 32, in <genexpr>(.0)
#      25 x = pulp.LpVariable.dicts(
#      26     "x",
#      27     ((e, v, t) for e in Exams for v in Venues for t in Timeslots),
#      28     cat="Binary"
#      29 )
#      31 #Objective Function
# ---> 32 problem += lpSum(cost[e, v, t] * x[e, v, t] for e in Exams for v in Venues for t in Timeslots)
#      34 #Constraint 1: Each exam must be assigned to exactly one venue and time
#      35 for e in Exams:
#
# KeyError: (Ellipsis, Ellipsis, (1, 1))
