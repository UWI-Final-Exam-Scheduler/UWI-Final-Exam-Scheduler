# %% [markdown]
#  $\min\limits_{x_{i,j}}$ $\sum_{i=1}^{n-1} \sum_{\substack{i` \neq i \\ i`=i+1}}^{n} \ (S_{i,i`}) . (C_{i,i`})   $
#
#  $ $
#  $ $
#
#  Subject to:
#
#  $ $
#
#  i. $(T_{i,i`}).d(k_{i,i`}) + S_{i,i`} \geq (1)T_{i,i`} \quad  \forall i,\, i' \neq i $
#
#  $ $
#
#  ii. $ (S_{i,i`}) \geq 0 $
#
# $ $
#
# iii. $\sum_{j=1}^{n} \ (x_{i,j}) = 1 \quad \forall i $
#
# $ $
#
# iv. $(x_{i,j,v}) + (x_{i`,j,v}) \leq 1 \quad \forall j, (i,i`), where (T_{i,i`}) = 1$
#
#
# $ $
#
# v. $N_i (x_{i,j,v}) \leq Cap_v(x_{i,j,v}) \quad \forall i, j, v $
#
# $ $
#
# Course $i$
# Timeslot $j$
# Venues $v$
#
# $S_{i , i`} $ - deviation from goal (at least one day between $i$ and $i`$)
# $C_{i , i`} $  - number of students doing $i$ and $i`$
# $T_{i , i`}$   - $1$ if at least one student doing $i$ and $i`$, $0$ otherwise
# $d(k_{i,i`}) $  -  time in days between $i$ and $i`$'s exams
# $x_{i,j,v}$ - $1$ if course $i$ is scheduled at time $j$ in venue $v$, $0$ otherwise
# $N_i$ - Number of students that do course $i$
# $Cap_v$ - Capacity of venue $v$
# <br>
# Respective constraints
# i. Given that at least 1 student is doing courses $i$ and $i`$ , ensures the students have at least 1 day in between the exams $i$ and $i`$ unless absolutely necessary to give less.
# ii. Make sure the Slack is non-negative
# iii. Ensure an exam is assigned only 1 timeslot
# iv.  Ensure that a student is not scheudled more than 1 exam for the same timeslot.
# v.  Ensure that the capacity of the venue is not exceeded by the number of students doing course $i$.

# %%
import polars as pr
import pulp as pl
from itertools import combinations

# %%
# Load data
courses_df = pr.read_csv("Test data/sem2_courses.csv")
venues_df = pr.read_csv("Test data/venues.csv")
clash_df = pr.read_csv("Test data/clash_matrix.csv")
enrollments_df = pr.read_csv("Test data/enrollments.csv")

# %%
courses_df = courses_df.with_columns(
    (
        pr.col("Subj Code").str.strip_chars() +
        pr.col("Crse Numb").cast(pr.Utf8).str.zfill(4)
    ).alias("course_code")
)

courses = (
    courses_df
    .select("course_code")
    .unique()
    .to_series()
    .to_list()
)

venues = venues_df["Venue Name"].to_list()

# timeslots: 15 days, 3 slots per day
timeslots = [f"D{d}_S{s}" for d in range(1, 16) for s in range(1, 4)]

# %%
# Parameters
Cap = dict(zip(
    venues_df["Venue Name"].to_list(),
    venues_df["Capacity"].to_list()
))

# Number of students in each course
N_df = (
    enrollments_df
    .group_by("Course Code")
    .len()
)

N = dict(zip(
    N_df["Course Code"].to_list(),
    N_df["len"].to_list()
))

# Clash matrix
C = {}
T = {}

for row in clash_df.iter_rows(named=True):
    i = row["Course 1"]
    j = row["Course 2"]
    val = row["Clash Count"]

    C[(i, j)] = val
    C[(j, i)] = val

    T[(i, j)] = 1 if val > 0 else 0
    T[(j, i)] = T[(i, j)]

# Only keep actual clash pairs
pairs = [
    (i, ip)
    for (i, ip) in combinations(courses, 2)
    if T.get((i, ip), 0) == 1
]


# Timeslot day map
slot_day = {j: int(j.split("_")[0][1:]) for j in timeslots}

# Days between timeslots
gap = {
    (j, jp): abs(slot_day[j] - slot_day[jp])
    for j in timeslots
    for jp in timeslots
}

# %%
# Model definition
model = pl.LpProblem("Exam_Timetabling", pl.LpMinimize)

# %%
# Variables
# x[i,j,v] = 1 if course i is in timeslot j at venue v
x = pl.LpVariable.dicts(
    "x",
    [(i, j, v) for i in courses for j in timeslots for v in venues],
    cat=pl.LpBinary
)

# Slack variable
s = pl.LpVariable.dicts(
    "s",
    pairs,
    lowBound=0,
    cat=pl.LpContinuous
)

# y[i,ip,j,jp] = 1 if i is in j and ip is in jp
y = pl.LpVariable.dicts(
    "y",
    [
        (i, ip, j, jp)
        for (i, ip) in pairs
        for j in timeslots
        for jp in timeslots
    ],
    cat=pl.LpBinary
)

# %%
#Objective
model += pl.lpSum(C[(i, ip)] * s[(i, ip)] for (i, ip) in pairs)

# %%
# Constraints
# Each course assigned exactly once
for i in courses:
    model += pl.lpSum(
        x[(i, j, v)] for j in timeslots for v in venues
    ) == 1

# No conflicting pair in same timeslot
for (i, ip) in pairs:
    if T[(i, ip)] == 1:
        for j in timeslots:
            model += (
                pl.lpSum(x[(i, j, v)] for v in venues) +
                pl.lpSum(x[(ip, j, v)] for v in venues)
            ) <= 1

# # Venue capacity
for i in courses:
    for j in timeslots:
        for v in venues:
            model += N[i] * x[(i, j, v)] <= Cap[v]

# # At most one exam in a venue in a timeslot
# for j in timeslots:
#     for v in venues:
#         model += pl.lpSum(x[(i, j, v)] for i in courses) <= 1

# # Link y variables to slot choices
# for (i, ip) in pairs:
#     for j in timeslots:
#         for jp in timeslots:
#             model += y[(i, ip, j, jp)] <= pl.lpSum(x[(i, j, v)] for v in venues)
#             model += y[(i, ip, j, jp)] <= pl.lpSum(x[(ip, jp, v)] for v in venues)
#             model += y[(i, ip, j, jp)] >= (
#                 pl.lpSum(x[(i, j, v)] for v in venues) +
#                 pl.lpSum(x[(ip, jp, v)] for v in venues) - 1
#             )

# Soft spacing constraint
for (i, ip) in pairs:
    model += (
        pl.lpSum(
            gap[(j, jp)] * y[(i, ip, j, jp)]
            for j in timeslots
            for jp in timeslots
        )
        + s[(i, ip)]
        >= T[(i, ip)]
    )

# %%
# Solve
solver = pl.PULP_CBC_CMD(msg=True)
model.solve(solver)
# Out:
# -1

# %%
# Output
print("Status:", pl.LpStatus[model.status])
print("Objective:", pl.value(model.objective))

print("\nAssignments:")
for i in courses:
    for j in timeslots:
        for v in venues:
            if pl.value(x[(i, j, v)]) > 0.5:
                print(f"{i} -> {j} in {v}")
# Out:
# Status: Infeasible
# Objective: 0.0
#
# Assignments:
# FOUN1106 -> D1_S3 in The Temporary Room at Chemistry
# CRMJ6004 -> D11_S1 in JFK Auditorium
# PUHE6014 -> D14_S2 in Main Drawing Office (MD3)
# CIEN6000 -> D14_S2 in The Temporary Room at Nat Sci
# MEDC0301 -> D7_S2 in JFK Auditorium
# ECNG1013 -> D4_S1 in Main Drawing Office (MD3)
# ECNG3021 -> D2_S1 in Main Drawing Office (MD3)
# TOUR1001 -> D13_S1 in JFK Auditorium
# INSB2007 -> D11_S2 in JFK Auditorium
# MATH3278 -> D2_S2 in Main Drawing Office (MD3)
# INBU3002 -> D4_S1 in JFK Auditorium
# ECON2000 -> D4_S3 in The Temporary Room at Nat Sci
# COMS2202 -> D1_S1 in JFK Auditorium
# MUSC0201 -> D12_S1 in JFK Auditorium
# RENT6006 -> D6_S3 in Main Drawing Office (MD3)
# PSYC2011 -> D5_S2 in Main Drawing Office (MD3)
# PSMA6003 -> D1_S1 in JFK Auditorium
# EDME6121 -> D11_S2 in The Temporary Room at Nat Sci
# GOVT3066 -> D2_S2 in Mechanical Design Office (MD2)
# CVNG3002 -> D6_S2 in The Temporary Room at Nat Sci
# ...

# %%
print("\nSlack values:")
for (i, ip) in pairs:
    print(f"{i}, {ip}: {pl.value(s[(i, ip)])}")
# Out:
# Slack values:
# FOUN1106, FOUN1103: 0.0
# FOUN1106, FOUN1001: 0.0
# FOUN1106, FOUN1210: 0.0
# CRMJ6004, CRMJ6001: 0.0
# CRMJ6004, CRMJ6002: 0.0
# CRMJ6004, CRMJ1001: 0.0
# CRMJ6004, CRMJ6003: 0.0
# PUHE6014, PUHE6013: 0.0
# PUHE6014, PUHE6002: 0.0
# CIEN6000, CIEN6001: 0.0
# MEDC0301, MEDC0501: 0.0
# MEDC0301, MEDC6925: 0.0
# MEDC0301, MEDC5402: 0.0
# MEDC0301, MEDC5400: 0.0
# MEDC0301, MEDC6821: 0.0
# MEDC0301, MEDC0201: 0.0
# MEDC0301, MEDC6820: 0.0
# MEDC0301, MEDC0101: 0.0
# MEDC0301, MEDC5401: 0.0
# MEDC0301, MEDC0401: 0.0
# MEDC0301, MEDC6822: 0.0
# ECNG1013, ECNG3021: 0.0
# ECNG1013, ECNG1000: 0.0
# ECNG1013, ECNG2012: 0.0
# ECNG1013, ECNG3030: 0.0
# ECNG1013, ECNG2011: 0.0
# ECNG1013, ECNG3001: 0.0
# ECNG1013, ECNG3006: 0.0
# ECNG1013, ECNG3015: 0.0
# ECNG1013, ECNG3002: 0.0
# ECNG1013, ECNG3023: 0.0
# ECNG1013, ECNG1011: 0.0
# ECNG1013, ECNG2013: 0.0
# ECNG3021, ECNG1000: 0.0
# ECNG3021, ECNG2012: 0.0
# ECNG3021, ECNG3030: 0.0
# ECNG3021, ECNG2011: 0.0
# ...
